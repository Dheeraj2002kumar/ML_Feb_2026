# %% [markdown]
# # Import pandas

# %%
import pandas as %pd

# %% [markdown]
# ## opening a local csv file
# [https://www.kaggle.com/datasets/saurabhkumargupta23/frtbre]()

# %%
df = pd.read_csv('./Dataset/aug_test.csv')
df
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# ## Opening a csv file from a URL

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %% [markdown]
# ## Sep Parameter
#
# [https://www.kaggle.com/datasets/deependraverma13/movie-titles-metadata-tsv-file]()

# %%
pd.read_csv("./Dataset/movie_titles_metadata.tsv", sep='\t', 
            names = ['sno', 'name', 'release_year', 'rating', 'votes', 
                    'genres'])
# Out:
#       sno                        name release_year  rating     votes  \
# 0      m0  10 things i hate about you         1999     6.9   62847.0
# 1      m1  1492: conquest of paradise         1992     6.2   10421.0
# 2      m2                  15 minutes         2001     6.1   25854.0
# 3      m3       2001: a space odyssey         1968     8.4  163227.0
# 4      m4                     48 hrs.         1982     6.9   22289.0
# ..    ...                         ...          ...     ...       ...
# 612  m612                    watchmen         2009     7.8  135229.0
# 613  m613                         xxx         2002     5.6   53505.0
# 614  m614                       x-men         2000     7.4  122149.0
# 615  m615          young frankenstein         1974     8.0   57618.0
# 616  m616                   zulu dawn         1979     6.4    1911.0
#
#                                                 genres
# 0                                 ['comedy' 'romance']
# ...

# %% [markdown]
# ## Index_col parameter

# %%
pd.read_csv('./Dataset/aug_test.csv', index_col='enrollee_id')
# Out:
#                  city  city_development_index  gender  \
# enrollee_id
# 32403         city_41                   0.827    Male
# 9858         city_103                   0.920  Female
# 31806         city_21                   0.624    Male
# 27385         city_13                   0.827    Male
# 27724        city_103                   0.920    Male
# ...               ...                     ...     ...
# 1289         city_103                   0.920    Male
# 195          city_136                   0.897    Male
# 31762        city_100                   0.887    Male
# 7873         city_102                   0.804    Male
# 12215        city_102                   0.804    Male
#
#                  relevent_experience enrolled_university education_level  \
# enrollee_id
# 32403        Has relevent experience    Full time course        Graduate
# 9858         Has relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# ## Header parameter
#
# [https://www.kaggle.com/datasets/diyanandy/testcsv]()

# %%
pd.read_csv('./Dataset/test/test.csv')
# Out:
#             id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont4  \
# 0            0    B    B    B    C    B    B    A    E    E  ...  0.476739
# 1            5    A    B    A    C    B    C    A    E    C  ...  0.285509
# 2           15    B    A    A    A    B    B    A    E    D  ...  0.697272
# 3           16    B    B    A    C    B    D    A    E    A  ...  0.719306
# 4           17    B    B    A    C    B    C    A    E    C  ...  0.313032
# ...        ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...       ...
# 199995  499987    B    A    A    C    B    D    A    E    E  ...  0.287454
# 199996  499990    B    A    A    C    B    B    A    E    C  ...  0.794881
# 199997  499991    A    B    B    C    B    B    A    E    C  ...  0.514487
# 199998  499994    A    A    A    C    B    D    A    D    A  ...  0.286144
# 199999  499995    A    A    A    C    B    D    A    E    A  ...  0.286755
#
# ...

# %%
pd.read_csv('./Dataset/test/test.csv', header=1)
# Out:
#              0  B B.1 B.2  C B.3 B.4  A  E E.1  ... 0.4767390451101133  \
# 0            5  A   B   A  C   B   C  A  E   C  ...           0.285509
# 1           15  B   A   A  A   B   B  A  E   D  ...           0.697272
# 2           16  B   B   A  C   B   D  A  E   A  ...           0.719306
# 3           17  B   B   A  C   B   C  A  E   C  ...           0.313032
# 4           19  B   B   B  C   B   B  A  E   E  ...           0.489711
# ...        ... ..  ..  .. ..  ..  .. .. ..  ..  ...                ...
# 199994  499987  B   A   A  C   B   D  A  E   E  ...           0.287454
# 199995  499990  B   A   A  C   B   B  A  E   C  ...           0.794881
# 199996  499991  A   B   B  C   B   B  A  E   C  ...           0.514487
# 199997  499994  A   A   A  C   B   D  A  D   A  ...           0.286144
# 199998  499995  A   A   A  C   B   D  A  E   A  ...           0.286755
#
#         0.37634964704960105  0.3378838967546349  0.3218317548420124  \
# ...

# %% [markdown]
# ## use_cols parameter

# %%
pd.read_csv('./Dataset/aug_test.csv')
# Out:
#       enrollee_id      city  city_development_index  gender  \
# 0           32403   city_41                   0.827    Male
# 1            9858  city_103                   0.920  Female
# 2           31806   city_21                   0.624    Male
# 3           27385   city_13                   0.827    Male
# 4           27724  city_103                   0.920    Male
# ...           ...       ...                     ...     ...
# 2124         1289  city_103                   0.920    Male
# 2125          195  city_136                   0.897    Male
# 2126        31762  city_100                   0.887    Male
# 2127         7873  city_102                   0.804    Male
# 2128        12215  city_102                   0.804    Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# ...

# %%
# if you need specific column then use 'usecols=['column_name1', 'column_name2']'
pd.read_csv('./Dataset/aug_test.csv', usecols=['enrollee_id', 'gender',
                                              'education_level'])
# Out:
#       enrollee_id  gender education_level
# 0           32403    Male        Graduate
# 1            9858  Female        Graduate
# 2           31806    Male     High School
# 3           27385    Male         Masters
# 4           27724    Male        Graduate
# ...           ...     ...             ...
# 2124         1289    Male        Graduate
# 2125          195    Male         Masters
# 2126        31762    Male  Primary School
# 2127         7873    Male     High School
# 2128        12215    Male         Masters
#
# [2129 rows x 3 columns]

# %% [markdown]
# ## Skiprows/nrows parameter

# %%
pd.read_csv('./Dataset/aug_test.csv', nrows=100)
# Out:
#     enrollee_id      city  city_development_index  gender  \
# 0         32403   city_41                   0.827    Male
# 1          9858  city_103                   0.920  Female
# 2         31806   city_21                   0.624    Male
# 3         27385   city_13                   0.827    Male
# 4         27724  city_103                   0.920    Male
# ..          ...       ...                     ...     ...
# 95         2934   city_75                   0.939    Male
# 96        12919  city_103                   0.920  Female
# 97         4386   city_21                   0.624    Male
# 98        22462   city_21                   0.624     NaN
# 99        13988  city_103                   0.920     NaN
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience    Full time course        Graduate
# 1   Has relevent experience       no_enrollment        Graduate
# 2    No relevent experience       no_enrollment     High School
# ...

# %% [markdown]
# ## Encoding parameter
#
# [zomato dataset](https://www.kaggle.com/datasets/rajeshrampure/zomato-dataset)

# %%
pd.read_csv('./Dataset/zomato/zomato.csv', nrows=100, encoding='latin-1')
# Out:
#                                                   url  \
# 0   https://www.zomato.com/bangalore/jalsa-banasha...
# 1   https://www.zomato.com/bangalore/spice-elephan...
# 2   https://www.zomato.com/SanchurroBangalore?cont...
# 3   https://www.zomato.com/bangalore/addhuri-udupi...
# 4   https://www.zomato.com/bangalore/grand-village...
# ..                                                ...
# 95  https://www.zomato.com/bangalore/vi-ras-bar-an...
# 96  https://www.zomato.com/bangalore/kaggis-banash...
# 97  https://www.zomato.com/bangalore/ayda-persian-...
# 98  https://www.zomato.com/bangalore/chatar-patar-...
# 99  https://www.zomato.com/bangalore/polar-bear-1-...
#
#                                               address  \
# 0   942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1   2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2   1112, Next to KIMS Medical College, 17th Cross...
# 3   1st Floor, Annakuteera, 3rd Stage, Banashankar...
# ...

# %% [markdown]
# ## Skip bad line
#
# [Bx-Books dataset](https://www.kaggle.com/datasets/alizaynoor/bx-books-csv)

# %%
pd.read_csv("./Dataset/BX-Books/BX-Books.csv",
            sep=';', 
            encoding='latin-1',
            on_bad_lines='skip'
           )
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_23820\1286283848.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("./Dataset/BX-Books/BX-Books.csv",
#         0195153448                                Classical Mythology  \
# 0       0002005018                                       Clara Callan
# 1       0060973129                               Decision in Normandy
# 2       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3       0393045218                             The Mummies of Urumchi
# 4       0399135782                             The Kitchen God's Wife
# ...            ...                                                ...
# 271354  0440400988                         There's a Bat in Bunk Five
# 271355  0525447644                            From One to One Hundred
# 271356  006008667X  Lily Dale : The True Story of the Town that Ta...
# ...

# %% [markdown]
# ## dtypes parameter

# %%
pd.read_csv('./Dataset/aug_test.csv', dtype={'training_hours': int}).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2129 entries, 0 to 2128
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             2129 non-null   int64
#  1   city                    2129 non-null   object
#  2   city_development_index  2129 non-null   float64
#  3   gender                  1621 non-null   object
#  4   relevent_experience     2129 non-null   object
#  5   enrolled_university     2098 non-null   object
#  6   education_level         2077 non-null   object
#  7   major_discipline        1817 non-null   object
#  8   experience              2124 non-null   object
#  9   company_size            1507 non-null   object
#  10  company_type            1495 non-null   object
#  11  last_new_job            2089 non-null   object
#  12  training_hours          2129 non-null   int32
# dtypes: float64(1), int32(1), int64(1), object(10)
# memory usage: 208.0+ KB

# %% [markdown]
# ## Handling dates
#
# [IPL Matches 2008-2020 dataset](https://www.kaggle.com/datasets/lizasareen/ipl-match-dataset-for-year-2008-2020)

# %%
pd.read_csv('./Dataset/IPL Matches 2008-2020.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    object
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
pd.read_csv('./Dataset/IPL Matches 2008-2020.csv', parse_dates=['date']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %% [markdown]
# ## Convertors

# %%
def rename(name):
    if name == "Royal Challengers Bangalore":
        return "RCB"
    else:
        return name

rename("Royal Challengers Bangalore")
# Out:
# 'RCB'

# %%
pd.read_csv("./Dataset/IPL Matches 2008-2020.csv", converters={'team1': rename})
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# ## na_values parameter

# %%
pd.read_csv('./Dataset/aug_test.csv', na_values=['Female']) 
# all Female value will change in NaN 
# it will useful when we get '-', ',' these value we will
# take as a NaN
# Out:
#       enrollee_id      city  city_development_index gender  \
# 0           32403   city_41                   0.827   Male
# 1            9858  city_103                   0.920    NaN
# 2           31806   city_21                   0.624   Male
# 3           27385   city_13                   0.827   Male
# 4           27724  city_103                   0.920   Male
# ...           ...       ...                     ...    ...
# 2124         1289  city_103                   0.920   Male
# 2125          195  city_136                   0.897   Male
# 2126        31762  city_100                   0.887   Male
# 2127         7873  city_102                   0.804   Male
# 2128        12215  city_102                   0.804   Male
#
#           relevent_experience enrolled_university education_level  \
# 0     Has relevent experience    Full time course        Graduate
# 1     Has relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# ## Loading a huge dataset in chunks

# %%
dfs = pd.read_csv('./Dataset/aug_test.csv', chunksize=500)

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (500, 13)
# (500, 13)
# (500, 13)
# (500, 13)
# (129, 13)

# %%
# chunk will help in large dataset
# when we have 1000000 rows data and if our PC can not handle it 
# then use chunksize operation to convert into chunk and use with for loop
